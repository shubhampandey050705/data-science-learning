# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv(r"C:\Users\Shubham Pandey\Downloads\multiple_linear_regression_dataset.csv")
dataset
# Out:
#     age  experience  income
# 0    25           1   30450
# 1    30           3   35670
# 2    47           2   31580
# 3    32           5   40130
# 4    43          10   47830
# 5    51           7   41630
# 6    28           5   41340
# 7    33           4   37650
# 8    37           5   40250
# 9    39           8   45150
# 10   29           1   27840
# 11   47           9   46110
# 12   54           5   36720
# 13   51           4   34800
# 14   44          12   51300
# 15   41           6   38900
# 16   58          17   63600
# 17   23           1   30870
# 18   44           9   44190
# 19   37          10   48700

# %%
dataset.isnull().sum()
# Out:
# age           0
# experience    0
# income        0
# dtype: int64

# %%
sns.pairplot(data=dataset) #from data we can say that data follows linearity
plt.show()

# %%
sns.heatmap(data=dataset.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
x= dataset.iloc[:, :-1] # Independent variables
y= dataset["income"] # Dependent variable

# %%
dataset.shape
# Out:
# (20, 3)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr= LinearRegression()
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
lr.score(x_test, y_test)*100 #accuracy of the model is 93.87 , whic is very good
# Out:
# 93.87098237077886

# %%
lr.coef_
# Out:
# array([-101.0592335 , 2154.80549277])

# %%
lr.intercept_
# Out:
# 31465.056418503933

# %%
# y-m1x1 +m2x2+c
# income=  -101.0592335*age +2154.80549277*Experience +31465.056418503933

# %%
lr.predict(x_test)
# Out:
# array([31093.38107376, 31295.49954076, 40250.46080162, 34897.6958918 ])
